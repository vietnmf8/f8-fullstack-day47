# %%
npm i module-alias

# %%
//package.json

{
    "scripts": {
        "dev": "node --watch server.js"
    },
    "dependencies": {
        "express": "^5.2.1"
    },
	"_moduleAliases": {
		"@": "./src"
	}
}

# %%
//server.js: Thêm vào đầu file trên cùng
require('module-alias/register')

# %%
// jsconfig.json

{
    "compilerOptions": {
        "baseUrl": ".",
        "paths": {
            "@/*": ["./src/*"]
        }
    }
}

# %%
// .gitignore

node_modules
