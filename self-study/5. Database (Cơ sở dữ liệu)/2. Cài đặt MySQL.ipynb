# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tạo Table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
npm i mysql2

# %%
// src/config/database.js

const mysql = require("mysql2/promise");

const pool = mysql.createPool({
    host: "localhost",
    user: "viet",
    password: "Viet251001",
    database: "blog_dev",
    waitForConnections: true,
    connectionLimit: 10,
    maxIdle: 10,
    idleTimeout: 60000,
    queueLimit: 0,
    enableKeepAlive: true,
    keepAliveInitialDelay: 0,
});

module.exports = pool;

# %%
// server.js

// Chỉ cần require vào thôi
require("@/config/database");

# %%
/* Các câu query tương ứng với CRUD */

/* Lấy ra */
/* 
	Select:	Lấy
	*:		Tất cả
	FROM:	Từ
	posts:	Bảng posts
 */

SELECT * FROM posts;

---

/* Lấy ra các field: id, title, slug từ bảng posts */
SELECT id, title, slug FROM posts;

/* Lấy ra các field: id từ bảng posts và đặt tên thay thế là newId */
SELECT id as newId FROM posts;

# %%
-- Lấy tất cả từ bảng posts
-- SELECT * FROM posts;

-- WHERE: Với điều kiện id = 1
-- SELECT * FROM posts WHERE id = 1;

-- DELETE: Xoá
-- DELETE FROM posts WHERE id = 3;

-- UPDATE: Cập nhật
-- UPDATE posts SET title = "Title 222", slug = "title-222" WHERE id = 2;

-- INSERT: Chèn một record mới
INSERT INTO posts (title, slug, description, content) values ("Title 4", "title-4", "Mo ta 4", "Noi dung 4");

# %%
//src/controllers/post.controller.js

const pool = require("@/config/database");

/* Lấy toàn bộ danh sách Task */
const getAll = async (req, res) => {
    const [rows, fields] = await pool.query("select * from posts;"); // query lấy chính câu truy vấn đó
    res.success(rows);
};

/* Lấy chi tiết 1 task */
const getOne = (req, res) => {};

/* Tạo task mới */
const create = (req, res) => {};

module.exports = { getAll, getOne, create };
